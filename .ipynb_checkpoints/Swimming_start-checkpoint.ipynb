# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from prophet import Prophet

# %%
df = pd.read_csv('Olympic_Swimming_Results_1912to2020.csv')
df = df.dropna(how="any")
df
# Out:
#        Location  Year Distance (in meters)      Stroke  Relay? Gender Team  \
# 0         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 1         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 2         Tokyo  2020                 100m  Backstroke       0    Men  USA
# 3         Tokyo  2020                 100m  Backstroke       0    Men  ITA
# 4         Tokyo  2020                 100m  Backstroke       0    Men  CHN
# ...         ...   ...                  ...         ...     ...    ...  ...
# 4353  Stockholm  1912                4x100   Freestyle       1  Women  AUT
# 4355  Stockholm  1912                4x200   Freestyle       1    Men  AUS
# 4356  Stockholm  1912                4x200   Freestyle       1    Men  USA
# 4357  Stockholm  1912                4x200   Freestyle       1    Men  GBR
# 4358  Stockholm  1912                4x200   Freestyle       1    Men  GER
#
#                                                 Athlete          Results  Rank
# 0                                          Evgeny Rylov            51.98     1
# 1                                    Kliment Kolesnikov               52     2
# 2                                           Ryan Murphy            52.19     3
# 3                                         Thomas Ceccon             52.3     4
# 4                                              Jiayu Xu            52.51     4
# ...                                                 ...              ...   ...
# 4353  Margarete Adler, Bertha Zahourek, Josephine St...  00:06:17.000000     4
# 4355  Malcolm Champion, Cecil Healy, Harold H. Hardw...  00:10:11.200000     1
# 4356  Duke Paoa Kahanamoku, Harry J. Hebner, Perry M...  00:10:20.200000     2
# 4357  Thomas Sidney Battersby, Henry Taylor, John Ga...  00:10:28.600000     3
# 4358  Georg Kunisch, Kurt Bretting, Oscar Schiele, M...  00:10:37.000000     4
#
# [4317 rows x 10 columns]

# %%
def to_seconds(time_str):
    # Handle NaN values and "Didnt qualify"
    if pd.isna(time_str) or time_str == "Disqualified" or time_str == "Did not start" or  time_str == "Did not finish":
        return None    
    # If it's already a number, return it as a float
    if isinstance(time_str, (int, float)):
        return float(time_str)
    
    # Convert to string if it's not already
    time_str = str(time_str)
    
    # Remove any non-digit characters except colon and period
    time_str = re.sub(r'[^\d:.]', '', time_str)
    
    # Split the time string by colon
    parts = time_str.split(':')
    
    if len(parts) == 1:
        # Format: seconds.milliseconds (e.g., 51.98)
        return float(parts[0])
    
    elif len(parts) == 2:
        # Format: minutes:seconds.milliseconds (e.g., 14:39.7)
        minutes, seconds = parts
        return float(minutes) * 60 + float(seconds)
    
    elif len(parts) == 3:
        # Format: hours:minutes:seconds.milliseconds
        hours, minutes, seconds = parts
        return float(hours) * 3600 + float(minutes) * 60 + float(seconds)
    
    else:
        # Unexpected format
        print(f"Unexpected time format: {time_str}")
        return None

# %%
df['Results'] = df['Results'].apply(to_seconds)
df
# Out:
#        Location  Year Distance (in meters)      Stroke  Relay? Gender Team  \
# 0         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 1         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 2         Tokyo  2020                 100m  Backstroke       0    Men  USA
# 3         Tokyo  2020                 100m  Backstroke       0    Men  ITA
# 4         Tokyo  2020                 100m  Backstroke       0    Men  CHN
# ...         ...   ...                  ...         ...     ...    ...  ...
# 4353  Stockholm  1912                4x100   Freestyle       1  Women  AUT
# 4355  Stockholm  1912                4x200   Freestyle       1    Men  AUS
# 4356  Stockholm  1912                4x200   Freestyle       1    Men  USA
# 4357  Stockholm  1912                4x200   Freestyle       1    Men  GBR
# 4358  Stockholm  1912                4x200   Freestyle       1    Men  GER
#
#                                                 Athlete  Results  Rank
# 0                                          Evgeny Rylov    51.98     1
# 1                                    Kliment Kolesnikov    52.00     2
# 2                                           Ryan Murphy    52.19     3
# 3                                         Thomas Ceccon    52.30     4
# 4                                              Jiayu Xu    52.51     4
# ...                                                 ...      ...   ...
# 4353  Margarete Adler, Bertha Zahourek, Josephine St...   377.00     4
# 4355  Malcolm Champion, Cecil Healy, Harold H. Hardw...   611.20     1
# 4356  Duke Paoa Kahanamoku, Harry J. Hebner, Perry M...   620.20     2
# 4357  Thomas Sidney Battersby, Henry Taylor, John Ga...   628.60     3
# 4358  Georg Kunisch, Kurt Bretting, Oscar Schiele, M...   637.00     4
#
# [4317 rows x 10 columns]

# %%
df_gold = df.loc[df["Rank"] == 1]
series_gold = df_gold["Team"].value_counts()
country_gold = pd.DataFrame(series_gold).head(10)
country_gold
# Out:
#       count
# Team
# USA     237
# AUS      61
# GDR      30
# HUN      25
# JPN      24
# NED      17
# CHN      14
# GER      13
# URS      11
# GBR      10

# %%
country_gold.plot(kind="pie", y="count", legend=False, autopct='%1.1f%%',title="Distribution of gold medals from 1912 to 2020")
plt.show()

# %%
series = df["Team"].value_counts()
series
country_df = pd.DataFrame(series)
country_top= country_df.head(10)
country_top
# Out:
#       count
# Team
# USA     888
# AUS     445
# GBR     286
# JPN     246
# GER     225
# CAN     198
# HUN     173
# GDR     144
# SWE     137
# FRA     137

# %%
country_top.plot(kind="pie", y="count", legend=False, autopct='%1.1f%%', title = "Distribution of # of players from 1912 to 2020")
plt.show()
# plt.legend(loc="lower right")

                # plot = df.plot.pie(y='hours', title="Title", legend=False, \
                #    autopct='%1.1f%%', explode=(0, 0, 0.1), \
                #    shadow=True, startangle=0)

# %%
df = df.set_index("Year")
df
# Out:
#        Location Distance (in meters)      Stroke  Relay? Gender Team  \
# Year
# 2020      Tokyo                 100m  Backstroke       0    Men  ROC
# 2020      Tokyo                 100m  Backstroke       0    Men  ROC
# 2020      Tokyo                 100m  Backstroke       0    Men  USA
# 2020      Tokyo                 100m  Backstroke       0    Men  ITA
# 2020      Tokyo                 100m  Backstroke       0    Men  CHN
# ...         ...                  ...         ...     ...    ...  ...
# 1912  Stockholm                4x100   Freestyle       1  Women  AUT
# 1912  Stockholm                4x200   Freestyle       1    Men  AUS
# 1912  Stockholm                4x200   Freestyle       1    Men  USA
# 1912  Stockholm                4x200   Freestyle       1    Men  GBR
# 1912  Stockholm                4x200   Freestyle       1    Men  GER
#
#                                                 Athlete  Results  Rank
# Year
# 2020                                       Evgeny Rylov    51.98     1
# 2020                                 Kliment Kolesnikov    52.00     2
# 2020                                        Ryan Murphy    52.19     3
# 2020                                      Thomas Ceccon    52.30     4
# 2020                                           Jiayu Xu    52.51     4
# ...                                                 ...      ...   ...
# 1912  Margarete Adler, Bertha Zahourek, Josephine St...   377.00     4
# 1912  Malcolm Champion, Cecil Healy, Harold H. Hardw...   611.20     1
# 1912  Duke Paoa Kahanamoku, Harry J. Hebner, Perry M...   620.20     2
# 1912  Thomas Sidney Battersby, Henry Taylor, John Ga...   628.60     3
# 1912  Georg Kunisch, Kurt Bretting, Oscar Schiele, M...   637.00     4
#
# [4317 rows x 9 columns]

# %%
popularity_gold = df_gold["Stroke"].value_counts()
popularity_gold
# Out:
# Stroke
# Freestyle            245
# Backstroke            76
# Breaststroke          72
# Butterfly             61
# Individual medley     54
# Medley                23
# Name: count, dtype: int64

# %%
popularity_gold_df= pd.DataFrame(popularity_gold)
popularity_gold_df
# Out:
#                    count
# Stroke
# Freestyle            245
# Backstroke            76
# Breaststroke          72
# Butterfly             61
# Individual medley     54
# Medley                23

# %%
popularity = df["Stroke"].value_counts()
popularity
# Out:
# Stroke
# Freestyle            1954
# Breaststroke          614
# Backstroke            602
# Butterfly             495
# Individual medley     424
# Medley                228
# Name: count, dtype: int64

# %%
popularity_df = pd.DataFrame(popularity)
popularity_df
# Out:
#                    count
# Stroke
# Freestyle           1954
# Breaststroke         614
# Backstroke           602
# Butterfly            495
# Individual medley    424
# Medley               228

# %%
plt.figure(figsize=(10, 6))
plt.bar(popularity_df.index, popularity_df["count"], label="The popularity in terms of #Partcipents from 1912 to 2020")
plt.bar(popularity_df.index, popularity_gold_df["count"],label="The popularity in terms of #Gold Medals from 1912 to 2020")
plt.legend(loc="best")
plt.show()

# %%
groupby_trend = df_gold.loc[(df_gold["Gender"] == "Men")&(df_gold["Distance (in meters)"] == "100m")&(df_gold["Stroke"] == "Backstroke")]
groupby_trend
# Out:
#        Location  Year Distance (in meters)      Stroke  Relay? Gender Team  \
# 0         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 224         Rio  2016                 100m  Backstroke       0    Men  USA
# 480      London  2012                 100m  Backstroke       0    Men  USA
# 736     Beijing  2008                 100m  Backstroke       0    Men  USA
# 992      Athens  2004                 100m  Backstroke       0    Men  USA
# 1248     Sydney  2000                 100m  Backstroke       0    Men  USA
# 1504    Atlanta  1996                 100m  Backstroke       0    Men  USA
# 1760  Barcelona  1992                 100m  Backstroke       0    Men  CAN
# 2008      Seoul  1988                 100m  Backstroke       0    Men  JPN
# 2256    Angeles  1984                 100m  Backstroke       0    Men  USA
# 2488     Moscow  1980                 100m  Backstroke       0    Men  SWE
# 2696   Montreal  1976                 100m  Backstroke       0    Men  USA
# 2911     Munich  1972                 100m  Backstroke       0    Men  JPN
# 3137       City  1968                 100m  Backstroke       0    Men  USA
# 3512       Rome  1960                 100m  Backstroke       0    Men  AUS
# 3632  Melbourne  1956                 100m  Backstroke       0    Men  AUS
# 3736   Helsinki  1952                 100m  Backstroke       0    Men  USA
# 3824     London  1948                 100m  Backstroke       0    Men  USA
# 3912     Berlin  1936                 100m  Backstroke       0    Men  USA
# 3999    Angeles  1932                 100m  Backstroke       0    Men  JPN
# 4075  Amsterdam  1928                 100m  Backstroke       0    Men  USA
# 4160      Paris  1924                 100m  Backstroke       0    Men  USA
# 4296  Stockholm  1912                 100m  Backstroke       0    Men  USA
#
#                    Athlete  Results  Rank
# 0             Evgeny Rylov    51.98     1
# 224            Ryan Murphy    51.97     1
# 480           Matt Grevers    52.16     1
# 736          Aaron Peirsol    52.54     1
# 992          Aaron Peirsol    54.06     1
# 1248     Lenny Krayzelburg    53.72     1
# 1504     Jeff Norman Rouse    54.10     1
# 1760        Mark Tewksbury    53.98     1
# 2008         Daichi Suzuki    55.05     1
# 2256    Richard John Carey    55.79     1
# 2488           Bengt Baron    56.53     1
# 2696   John Phillips Naber    55.49     1
# 2911         Tadashi Honda    60.41     1
# 3137       Charlie Hickcox    60.20     1
# 3512   David Egmont Theile    61.90     1
# 3632   David Egmont Theile    62.20     1
# 3736     Yoshinobu Oyakawa    65.40     1
# 3824  Allen Mcintyre Stack    66.40     1
# 3912  Adolph Gustav Kiefer    65.90     1
# 3999       Masaji Kiyokawa    68.60     1
# 4075   George Harold Kojac    68.20     1
# 4160   Warren Paoa Kealoha    73.20     1
# 4296       Harry J. Hebner    81.20     1

# %%
groupby_trend.plot(kind="line", x="Year", y= "Results", marker="*", label="The performance times in Male 100m Backstroke")
plt.show()

# %%
#2024 Top 3 Gold Medal winners by Country Prediction using Prophet

# %%
# Filter the dataset to include only gold medals (Rank == 1)
gold_medals = df[df['Rank'] == 1]

# %%
# Aggregate the total number of gold medals by each country across all years
# Ensure 'Team' is retained in the final DataFrame
total_gold_medals_per_country = gold_medals_per_country_per_year.groupby('Team')['Total_Gold_Medals'].sum().reset_index()

# Sort countries by the total number of gold medals in descending order
sorted_countries_by_medals = total_gold_medals_per_country.sort_values(by='Total_Gold_Medals', ascending=False)

# Check if the 'Team' column exists
print(sorted_countries_by_medals.columns)
# Out:
# Index(['Team', 'Total_Gold_Medals'], dtype='object')

# %%
# Check if the 'Team' column exists
print(sorted_countries_by_medals.columns)
# Out:
# Index(['Team', 'Total_Gold_Medals'], dtype='object')
